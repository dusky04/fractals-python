# %%
import matplotlib.pyplot as plt
import numpy as np
import random
# %matplotlib inline
import math

# %%
x = np.linspace(0, 4, 1000)
y = np.linspace(0, 4, 1000)
# a, b = np.meshgrid(x, y)

# %%
N = random.randint(4, 11)

# %%
s = [random.choice(["A", "B"]) for _ in range(N)]
s, len(s)
# Out:
# (['A', 'A', 'A', 'A', 'A', 'A', 'A'], 7)

# %%
hi  = []
for idx, i in enumerate(zip(a, b)):
    if idx%2==0:
        hi.append(i[0])
    else:
        hi.append(i[1])

# %%
hi = np.array(hi)

# %%
x0 = 0.5

# %%
x0 = 0.5
for idx, i in enumerate(zip(x, y)):
    if idx%2==0:
        r = i[0]
    else:
        r = i[1]

    x0 = r * x0 * (1-x0)
    lmd = 0
    for _ in range(len(s)):
        lmd += math.log(abs(r * (1 - 2*x0)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 11
#       9 lmd = 0
#      10 for _ in range(len(s)):
# ---> 11     lmd += math.log(abs(r * (1 - 2*x0)))
#
# ValueError: math domain error

# %%
len(next(zip(a, b))[0])
# Out:
# 1000

# %%
plt.imshow(a)

# %%
plt.imshow(b)

# %%
c = a+ b

# %%
plt.imshow(c)

# %%
c.shape
# Out:
# (1000, 1000)

# %%
c[0:2 ].shape
# Out:
# (2, 1000)

# %%
for i in c:
    print(i.shape)
# Out:
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# ...

# %%
p = np.sin(c)+1

# %%
plt.imshow(p)

# %%
x = np.linspace(-1, 1, 1000)
y = np.linspace(-1, 1, 1000)
c = x+y
print(c.shape)
p = np.sin(c) +1
# Out:
# (1000,)
# (1000,)

# %%
plt.imshow(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 plt.imshow(p)
#
# File c:\Users\Vaibhav Rastogi\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3476, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3455 @_copy_docstring_and_deprecators(Axes.imshow)
#    3456 def imshow(
#    3457     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3474     **kwargs,
#    3475 ) -> AxesImage:
# -> 3476     __ret = gca().imshow(
#    3477         X,
#    3478         cmap=cmap,
#    3479         norm=norm,
#    3480         aspect=aspect,
#    3481         interpolation=interpolation,
#    3482         alpha=alpha,
#    3483         vmin=vmin,
#    3484         vmax=vmax,
#    3485         origin=origin,
# ...
