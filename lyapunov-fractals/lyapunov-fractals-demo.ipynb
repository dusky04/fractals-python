# %%
from lyapunov_fractals import LyapunovFractals

# %%
L = LyapunovFractals(N=1000, seq="ABABB")
L.show_lyapunov_fractal(cmap="coolwarm")
L.save_lyapunov_fractal("lyapunov1.png", cmap="coolwarm")

# %%
L = LyapunovFractals(N=1000, seq="BBBBBBAAAAAA")
L.show_lyapunov_fractal(cmap="twilight", x_min=3.4, x_max=4, y_min = 2.5, y_max=3.4)
L.save_lyapunov_fractal("lyapunov2.png", cmap="twilight")
